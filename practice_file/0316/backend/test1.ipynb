# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\hi\appdata\local\programs\python\python312\lib\site-packages (4.1.1)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in c:\users\hi\appdata\local\programs\python\python312\lib\site-packages (from pyspark) (0.10.9.9)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("PySpark WorkCount Test").master("spark://localhost:7077").getOrCreate()

# %%
print("Spark Version:", spark.version)
# Out:
# Spark Version: 4.1.1
